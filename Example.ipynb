# %%
# !python run.py
# Out:
# 30

# %%
d = 50
e = 40
print(d+e)
# Out:
# 90

# %%
# test

# %%
import rasterio
dem = rasterio.open("elevation.tif")
array = dem.read(1)
from matplotlib import pyplot
# %matplotlib inline
pyplot.imshow(array, cmap='pink')
pyplot.show()
